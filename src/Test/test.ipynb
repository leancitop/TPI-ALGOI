# %%
import pandas as pd

data = {
    'region': ['Europe', 'America', 'Europe', 'America', 'Europe', 'Asia', 'Europe', 'America', 'Europe', 'Asia'],
    'categoria': ['Accessories', 'Accessories', 'Components', 'Components', 'Components', 'Accessories', 'Clothing', 'Clothing', 'Accessories', 'Components'],
    'subcategoria': ['Helmets', 'Helmets', 'Road Frames', 'Road Frames', 'Mountain Frames', 'Helmets', 'Shorts', 'Shorts', 'Pumps', 'Mountain Frames'],
    'producto': ['Sport-100 Helmet, Blue', 'Sport-100 Helmet, Blue', 'LL Road Frame - Red, 60', 'LL Road Frame - Red, 60', 'ML Mountain Frame - Black, 40', 'Sport-100 Helmet, Blue', 'Men\'s Sports Shorts, L', 'Men\'s Sports Shorts, L', 'Minipump', 'ML Mountain Frame - Black, 40'],
    'anio': [2018, 2019, 2018, 2018, 2018, 2019, 2018, 2018, 2018, 2019],
    'quarter': [4.0, 4.0, 3.0, 3.0, 3.0, 4.0, 4.0, 4.0, 4.0, 3.0],
    'mes': [11.0, 12.0, 8.0, 9.0, 9.0, 10.0, 11.0, 10.0, 12.0, 8.0],
    'valor_unitario_suma': [121.14, 40.38, 606.99, 606.99, 209.26, 80.76, 143.96, 71.98, 11.99, 627.78]
}

df = pd.DataFrame(data)

# %%
df.sort_values(['region','categoria'])
# Out:
#     region    categoria     subcategoria                       producto  anio  \
# 1  America  Accessories          Helmets         Sport-100 Helmet, Blue  2019
# 7  America     Clothing           Shorts         Men's Sports Shorts, L  2018
# 3  America   Components      Road Frames        LL Road Frame - Red, 60  2018
# 5     Asia  Accessories          Helmets         Sport-100 Helmet, Blue  2019
# 9     Asia   Components  Mountain Frames  ML Mountain Frame - Black, 40  2019
# 0   Europe  Accessories          Helmets         Sport-100 Helmet, Blue  2018
# 8   Europe  Accessories            Pumps                       Minipump  2018
# 6   Europe     Clothing           Shorts         Men's Sports Shorts, L  2018
# 2   Europe   Components      Road Frames        LL Road Frame - Red, 60  2018
# 4   Europe   Components  Mountain Frames  ML Mountain Frame - Black, 40  2018
#
#    quarter   mes  valor_unitario_suma
# 1      4.0  12.0                40.38
# ...

# %%
df
# Out:
#     region    categoria     subcategoria                       producto  anio  \
# 0   Europe  Accessories          Helmets         Sport-100 Helmet, Blue  2018
# 1  America  Accessories          Helmets         Sport-100 Helmet, Blue  2019
# 2   Europe   Components      Road Frames        LL Road Frame - Red, 60  2018
# 3  America   Components      Road Frames        LL Road Frame - Red, 60  2018
# 4   Europe   Components  Mountain Frames  ML Mountain Frame - Black, 40  2018
# 5     Asia  Accessories          Helmets         Sport-100 Helmet, Blue  2019
# 6   Europe     Clothing           Shorts         Men's Sports Shorts, L  2018
# 7  America     Clothing           Shorts         Men's Sports Shorts, L  2018
# 8   Europe  Accessories            Pumps                       Minipump  2018
# 9     Asia   Components  Mountain Frames  ML Mountain Frame - Black, 40  2019
#
#    quarter   mes  valor_unitario_suma
# 0      4.0  11.0               121.14
# ...
